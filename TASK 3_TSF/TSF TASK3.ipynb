# %% [markdown]
# #                    GRIP @ THE SPARKS FOUNDATION

# %% [markdown]
# ## TASK3- Exploratory Data Analysis on Superstore Data
#   #### (BY PRIYANKA PRIYADARSHINI MOHANTY)

# %% [markdown]
# ##### OBJECTIVE-
# ##### 1) To Perform Exploratory Data Analysis
# ##### 2) Find out business problems
# ##### 3) identify key areas for improving profits.

# %% [markdown]
# ## A) IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ALL THE REQUIRED LIBRARIES WERE IMPORTED.

# %% [markdown]
# ## B) LOADING DATA

# %%
data=pd.read_csv(r'file:///C:\Users\hp\Downloads\SampleSuperstore.csv')

# %% [markdown]
# DATA WAS LOADED FROM THE CSV FILE USING pd.read_csv

# %% [markdown]
# ## C) DEDUCING DATA

# %% [markdown]
# #### 1)THE NUMBER OF ROWS AND COLUMNS ARE:

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# #### 2)LISTING ALL THE COLUMNS

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# #### 3)FIRST 5 ROWS

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# #### 4)LAST 5 ROWS

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# #### 5)CHECKING THE DATA TYPE AND NON-NULL COUNT OF EACH COLUMN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# CONCLUSION

# %% [markdown]
# 1)We can see that the datatypes are correct and no change is required.

# %% [markdown]
# 2)No null values are present in the dataset.

# %% [markdown]
# #### 6)DATA DESCRIPTION

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
#  The fuction shows only continuous variables.It can be observed that the difference between max value and 75% of SALES and PROFIT is quite high which indicates there are large number of outliers.

# %% [markdown]
# #### 7)NUMBER OF UNIQUE VALUES PER COLUMN

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# CONCLUSION:

# %% [markdown]
# 1)There are only 4 types of shipping mode we will examine

# %% [markdown]
# 2)This dataset is given for 3 segments of people.

# %% [markdown]
# #### 8)DUPLICATE ROWS

# %% [markdown]
# ###### 8.1)The number of duplicated rows are:

# %%
data.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ###### 8.2)Removing the duplicate rows

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# #### 1)PAIRPLOT

# %%
sns.pairplot(data,hue='Sub-Category')

# %% [markdown]
# #### 2)PLOTTING CATEGORICAL VARIABLES

# %%
categorical_features=[feature for feature in data.columns if data[feature].dtype=='O' ]
for feature in categorical_features:
    if feature not in ['State','City','Sub-Category']:
        sns.catplot(x=feature, kind="count", palette="ch:.25", data=data)

# %% [markdown]
# #### 3)TOTAL SALES AND PROFIT OF THE COMPANY.

# %%
Sales_and_Profits=data.groupby("Segment").sum().iloc[:,[1,-1]].sum()
round(Sales_and_Profits,2)                                                     # Rounding Numerical entries to 2 decimal places
# Out:
# Sales     2297200.86
# Profit     286397.02
# dtype: float64

# %% [markdown]
# THUS, Total Sales = 2,296,195.56 USD

# %% [markdown]
# Total Profits = 286,241.42 USD

# %% [markdown]
# #### 4)TOP 10 STATES BY SALES AND PROFITS

# %%
Top_10_Sales =data.groupby("State").Sales.sum().nlargest(n =10)
Top_10_Profits =data.groupby("State").Profit.sum().nlargest(n =10)

# %% [markdown]
# ##### 4.1)Top 10 states by sales.

# %%
Top_10_Sales
# Out:
# State
# California      457687.6315
# New York        310876.2710
# Texas           170188.0458
# Washington      138641.2700
# Pennsylvania    116511.9140
# Florida          89473.7080
# Illinois         80166.1010
# Ohio             78258.1360
# Michigan         76269.6140
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
plt.style.use('seaborn')
Top_10_Sales.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Sales",fontsize =13)
plt.title("Top 10 States by Sales",fontsize =16)
plt.show()

# %% [markdown]
# California is having the highest sale.

# %% [markdown]
# ##### 4.2)Top 10 states by profit

# %%
Top_10_Profits
# Out:
# State
# California    76381.3871
# New York      74038.5486
# Washington    33402.6517
# Michigan      24463.1876
# Virginia      18597.9504
# Indiana       18382.9363
# Georgia       16250.0433
# Kentucky      11199.6966
# Minnesota     10823.1874
# Delaware       9977.3748
# Name: Profit, dtype: float64

# %%
plt.style.use('seaborn')
Top_10_Profits.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Profits",fontsize =13)
plt.title("Top 10 States by Profits",fontsize =16)
plt.show()

# %% [markdown]
# California is having the highest profit.

# %% [markdown]
# California and New York are far ahead of their competitor states in terms of profit as well as sales.

# %% [markdown]
# #### 5)TOP 10 CITIES BY SALES AND PROFITS

# %%
Top_10_city_sales=data.groupby("City").Sales.sum().nlargest(n =10)
Top_10_city_profit=data.groupby("City").Profit.sum().nlargest(n =10)

# %% [markdown]
# ###### 5.1)Top 10 Cities by Sales

# %%
Top_10_city_sales
# Out:
# City
# New York City    256368.1610
# Los Angeles      175851.3410
# Seattle          119540.7420
# San Francisco    112669.0920
# Philadelphia     109077.0130
# Houston           64504.7604
# Chicago           48539.5410
# San Diego         47521.0290
# Jacksonville      44713.1830
# Springfield       43054.3420
# Name: Sales, dtype: float64

# %%
plt.style.use('seaborn')
Top_10_city_sales.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("Cities", fontsize =13)
plt.ylabel("Total sale",fontsize =13)
plt.title("Top 10 cities by sales",fontsize =16)
plt.show()

# %% [markdown]
# New York City is having highest sales.

# %% [markdown]
# ###### 5.2)Top 10 cities by profits

# %%
Top_10_city_profit
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Lafayette        10018.3876
# Jackson           7581.6828
# Atlanta           6993.6629
# Minneapolis       6824.5846
# San Diego         6377.1960
# Name: Profit, dtype: float64

# %%
plt.style.use('seaborn')
Top_10_city_profit.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("Cities", fontsize =13)
plt.ylabel("Total Profits",fontsize =13)
plt.title("Top 10 cities by Profits",fontsize =16)
plt.show()

# %% [markdown]
# New York City is having the highest profit.

# %% [markdown]
# New York City and Los Angeles are far ahead of their competitor states in terms of profit as well as sales.

# %% [markdown]
# #### 6)DATA CORRELATION

# %%
corr=data.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# #### 6.1)CORRELATION PLOT

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr,annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# we infer that, 1)Sales and profits are positively correlated.

# %% [markdown]
# 2)Discount and Profits are Negatively correlated.

# %% [markdown]
# Hence we consider these cases and proceed further.

# %% [markdown]
# #### 7)
# #### Case-1 When Discount is 0

# %% [markdown]
# ###### 7.1)Profits v/s Sales

# %%
df=data[data['Discount']==0]
sns.relplot(x='Sales',y='Profit',data=df)

# %% [markdown]
# ###### 7.2)Profit distribution by sub-category

# %%
pivot=pd.pivot_table(df,index='Sub-Category',values='Profit')
pivot.plot(kind='bar')

# %% [markdown]
#  Copiers had highest profit and Machines had second highest profit.

# %% [markdown]
# ###### 7.3)Sales distribution by subcategory

# %%
pivot=pd.pivot_table(df,index='Sub-Category',values='Sales')
pivot.plot(kind='bar')

# %% [markdown]
#  Copiers had highest sale and Machines had second highest sales

# %% [markdown]
# #### Case-2:When discount is not zero.

# %% [markdown]
# ###### 7.4)Profits v/s Sales

# %%
df_new=data[data['Discount']!=0]
sns.relplot(x='Sales',y='Profit',hue='Discount',data=df_new)

# %% [markdown]
# ######  7.5)Profit  distribution by sub-category

# %%
pivot=pd.pivot_table(df_new,index='Sub-Category',values='Profit')
pivot.plot(kind='bar')

# %% [markdown]
# Here we see that copiers had highest Profit and Machines had highest loss

# %% [markdown]
# ###### 7.6)Sales distribution by sub-category

# %%
pivot=pd.pivot_table(df_new,index='Sub-Category',values='Sales')
pivot.plot(kind='bar')

# %% [markdown]
#  Here we see that copiers had highest sale and Machines had second highest sales
#
#  In above two graph we see that 'Machines' had second highest sale but due to large discount it is in loss and in second graph we see that sales in 'Fasteners','labels'and 'Art' category are so weak.so we have to concentrate on these sub-category businesses

# %% [markdown]
# Thus Discounts are triggering losses.

# %% [markdown]
# #### 8)CATEGORY WISE ANALYSIS

# %% [markdown]
# ###### 8.1)Discount

# %%
pivot=pd.pivot_table(data,index='Category',values='Discount')
pivot.plot(kind='bar')

# %% [markdown]
# ###### 8.2)Sales

# %%
pivot=pd.pivot_table(data,index='Category',values='Sales')
pivot.plot(kind='bar')

# %% [markdown]
# ##### 8.3)Profit

# %%
pivot=pd.pivot_table(data,index='Category',values='Profit')
pivot.plot(kind='bar')

# %% [markdown]
# From above three plot we say that

# %% [markdown]
# 1) More Discount is given in Furniture category and less Discount is given in Technology category businesses

# %% [markdown]
# 2) Sales of Technology category businesses are more as compared to Furniture category

# %% [markdown]
# 3) Profit of Technology category businesses are more as compared to Furniture category

# %% [markdown]
# #### 9)PROFIT DISTRIBUTION BY REGION

# %%
plt.figure(figsize = (12,4))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = data , x = "Region",y = "Profit" ,hue = "Category")
plt.show()

# %% [markdown]
# "Furniture" Category is the only loss making sector that to only in Central Region.So we will be working more on it.

# %% [markdown]
# #### 10)Investigating losses  in the Central region

# %%
#Grouping Data by Region and only slicing Data for Central Region from whole Data Set
Central = list(data.groupby("Region"))[0][1]

# %%
# Investing Further in cenral Region 
plt.figure(figsize = (12,4))
sns.set(font_scale=1.5, palette= "viridis")
sns.barplot(data =Central, x = "Category",y = "Profit" ,hue = "Ship Mode")
plt.title("Investigation of central region: Profit making(by Ship Mode)")
plt.show()

# %% [markdown]
# Losses are inccured in Furniture Cateory irrespective to ship mode in Central Region

# %% [markdown]
# #### 11)
# ###### 11.1)Investigating individual performance by states in the central region in sale of furniture

# %%
# Slicing Furniture Data from whole data set
gb_Category_Furniture =list(list(data.groupby("Region"))[0][1].groupby("Category"))[0][1]

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Sub-Category")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Sub Category)", fontsize = 20)
plt.show()

# %% [markdown]
# Texas and Illiois are only two states contributing to all the losses in Furniture category in the Central Region.

# %% [markdown]
# Losses in Tables Sub Category is significanlty high.

# %% [markdown]
# ##### 11.2) So, what is it they are doing diffrently?

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Discount" ,hue = "Sub-Category")
plt.title("Discounts provided by each state", fontsize = 20)
plt.show()

# %% [markdown]
# Texas and Illinois are only states providing discounts in the whole central region

# %% [markdown]
# Are these discounts driving sales up?.... NO!

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# #### From All these analysis we finally conclude that,

# %% [markdown]
# #### 1) If we give more Discount on products our sales goes increses but Profit get down.
# #### 2) In Technology category business we get more Profit as compared to other two business.These is because of we given less Discount.
# #### 3) Here we also focus on our Office Supplies category business because sales of these category is less as compared to other two.
# #### 4) Also Sales in 'Fasteners','labels'and 'Art' category are so weak.so we have to concentrate on these sub-category businesses..
# #### 5) For enhancing the profits , we need to sell more to the states which are liking our products like NEWYORK and CALIFORNIA .
# #### Hence To get good profit in any business you have to focus on increasing sales but not giving more discount
